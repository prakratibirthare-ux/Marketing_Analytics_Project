# %%
import pandas as pd

# %%
df = pd.read_csv("../data/Marketing_Analytics_Dataset_by_Slidescope.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("../data/Marketing_Analytics_Dataset_by_Slidescope.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\Documents\\Marketing_Analytics_Project\\notebooks'

# %%
os.listdir("../data")
# Out:
# ['Marketing_Analytics_Dataset_by_Slidescope (1).xlsx']

# %%
df = pd.read_excel("../data/Marketing_Analytics_Dataset_by_Slidescope (1).xlsx")

# %%
df.head()
# Out:
#         Date Region    Product Marketing_Channel Quarter    Spend  \
# 0 2023-01-01  North  Product C             Email      Q4  2410.89
# 1 2023-01-08   East  Product C     Search Engine      Q4   798.87
# 2 2023-01-15  North  Product D     Search Engine      Q2  3711.28
# 3 2023-01-22  North  Product B      Social Media      Q1   936.03
# 4 2023-01-29  South  Product A     Search Engine      Q4  3314.53
#
#    Impressions  Clicks  Conversions   Revenue     CTR    CPC     ROI
# 0         4106     793           22  15214.74  0.1931   3.04  5.3108
# 1         8338     296           21   7830.21  0.0355   2.70  8.8016
# 2         1309     202           24  16070.27  0.1543  18.37  3.3301
# 3         2055     377           36   5877.33  0.1835   2.48  5.2790
# 4         9831     960           23  12804.25  0.0977   3.45  2.8631

# %%
df.columns
# Out:
# Index(['Date', 'Region', 'Product', 'Marketing_Channel', 'Quarter', 'Spend',
#        'Impressions', 'Clicks', 'Conversions', 'Revenue', 'CTR', 'CPC', 'ROI'],
#       dtype='object')

# %%
df.shape
# Out:
# (100, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               100 non-null    datetime64[ns]
#  1   Region             100 non-null    object
#  2   Product            100 non-null    object
#  3   Marketing_Channel  100 non-null    object
#  4   Quarter            100 non-null    object
#  5   Spend              100 non-null    float64
#  6   Impressions        100 non-null    int64
#  7   Clicks             100 non-null    int64
#  8   Conversions        100 non-null    int64
#  9   Revenue            100 non-null    float64
#  10  CTR                100 non-null    float64
#  11  CPC                100 non-null    float64
#  12  ROI                100 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(3), object(4)
# memory usage: 10.3+ KB

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.isnull().sum()
# Out:
# Date                 0
# Region               0
# Product              0
# Marketing_Channel    0
# Quarter              0
# Spend                0
# Impressions          0
# Clicks               0
# Conversions          0
# Revenue              0
# CTR                  0
# CPC                  0
# ROI                  0
# dtype: int64

# %%
df["Conversion_Rate"] = df["Conversions"] / df["Clicks"]

# %%
df["Profit"] = df["Revenue"] - df["Spend"]

# %%
df.head()
# Out:
#         Date Region    Product Marketing_Channel Quarter    Spend  \
# 0 2023-01-01  North  Product C             Email      Q4  2410.89
# 1 2023-01-08   East  Product C     Search Engine      Q4   798.87
# 2 2023-01-15  North  Product D     Search Engine      Q2  3711.28
# 3 2023-01-22  North  Product B      Social Media      Q1   936.03
# 4 2023-01-29  South  Product A     Search Engine      Q4  3314.53
#
#    Impressions  Clicks  Conversions   Revenue     CTR    CPC     ROI  \
# 0         4106     793           22  15214.74  0.1931   3.04  5.3108
# 1         8338     296           21   7830.21  0.0355   2.70  8.8016
# 2         1309     202           24  16070.27  0.1543  18.37  3.3301
# 3         2055     377           36   5877.33  0.1835   2.48  5.2790
# 4         9831     960           23  12804.25  0.0977   3.45  2.8631
#
#    Conversion_Rate    Profit
# 0         0.027743  12803.85
# 1         0.070946   7031.34
# 2         0.118812  12358.99
# 3         0.095491   4941.30
# ...

# %%
df.to_excel("../data/clean_marketing_data.xlsx", index=False)
